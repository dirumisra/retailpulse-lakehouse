# %% [markdown]
# ## S1.4 — Databricks Workspace UI Walkthrough
# **Date completed:** May 2025
# **Status:** Complete — Awareness level
# **Note:** Every section covered in depth in its dedicated course section

# %% [markdown]
# ## Databricks Left Sidebar — Complete Reference
#
# ### Top Navigation
# | Section | Purpose | Course Section |
# |---------|---------|----------------|
# | Workspace | File browser — all notebooks and repos | Every session |
# | Catalog | Unity Catalog — databases, tables, volumes | S12 |
# | Jobs & Pipelines | Schedule and monitor pipelines | S11 |
# | Compute | Manage clusters and SQL Warehouses | S2, S13 |
# | Discover | Internal data marketplace | Awareness |
# | Marketplace | Third-party datasets and solutions | Awareness |
#
# ### SQL Section
# | Section | Purpose | Course Section |
# |---------|---------|----------------|
# | SQL Editor | Write and run SQL on Delta tables | S5 |
# | Dashboards | AI/BI Dashboards from Gold layer | S11 |
# | Genie Spaces | Natural language to SQL | S11 |
# | Alerts | Pipeline failure and data quality alerts | S11 |
# | Query History | Debug slow queries | S13 |
# | SQL Warehouses | Manage SQL compute | S11 |
#
# ### Data Engineering Section
# | Section | Purpose | Course Section |
# |---------|---------|----------------|
# | Runs | Monitor all job and pipeline runs | S11 |
# | Data Ingestion | Auto Loader and COPY INTO setup | S9 |
#
# ### AI/ML Section
# | Section | Purpose | Course Section |
# |---------|---------|----------------|
# | Playground | Test LLM prompts directly | S15 |
# | AI Gateway | Manage LLM API connections | S15 |
# | Experiments | MLflow experiment tracking | S15 |
# | Features | Feature Store for ML | S15 |
# | Models | MLflow model registry | S15 |
# | Serving | Deploy models as REST APIs | S15 |

# %% [markdown]
# ## Key Takeaways
#
# 1. Databricks UI is organised into 4 groups — Navigation, SQL, Data Engineering, AI/ML
# 2. Workspace = your daily file browser — notebooks and repos live here
# 3. Catalog = governance hub — all tables, schemas, permissions in one place
# 4. Jobs & Pipelines = production orchestration — schedule, monitor, alert
# 5. Runs = your morning check — did last night's pipeline succeed or fail?
# 6. Every menu item will be covered in depth in its dedicated course section
# 7. S1.4 is awareness — you now know where everything lives
