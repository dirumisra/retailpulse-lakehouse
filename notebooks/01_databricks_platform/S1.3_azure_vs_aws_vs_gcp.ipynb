# %% [markdown]
# ## S1.3 — Azure vs AWS vs GCP — Databricks Deployment
# **Date completed:** May 2025
# **Status:** Complete — Awareness level

# %% [markdown]
# ## Cloud Comparison — Azure vs AWS vs GCP
#
# | Feature | Azure | AWS | GCP |
# |---------|-------|-----|-----|
# | Storage | ADLS Gen2 | S3 | Cloud Storage |
# | Secrets | Key Vault | Secrets Manager | Secret Manager |
# | Identity | Azure AD | IAM | Cloud IAM |
# | Pipeline | Data Factory | AWS Glue | Dataflow |
# | Best for | Enterprise, banks | Startups, mature | ML workloads |
#
# **Our course uses Azure throughout — S8 covers it in depth.**

# %%
displayHTML("""
<div style="font-family:Arial,sans-serif;padding:16px;background:#1e1e1e;border-radius:10px;">

<h3 style="color:#888;font-size:12px;letter-spacing:1px;">DATABRICKS ON THREE CLOUDS — SAME PRODUCT, DIFFERENT LANDLORD</h3>

<div style="display:grid;grid-template-columns:1fr 1fr 1fr;gap:10px;margin-bottom:16px;">

<div style="background:#1a2a3a;border-radius:10px;overflow:hidden;">
<div style="background:#0078d4;padding:10px 14px;font-weight:bold;color:#fff;font-size:13px;">Microsoft Azure</div>
<div style="padding:12px 14px;font-size:11px;color:#ccc;line-height:1.9;">
<b style="color:#7ec8f7;">Storage:</b> ADLS Gen2<br/>
<b style="color:#7ec8f7;">Secrets:</b> Azure Key Vault<br/>
<b style="color:#7ec8f7;">Identity:</b> Azure Active Directory<br/>
<b style="color:#7ec8f7;">Pipeline:</b> Azure Data Factory<br/>
<b style="color:#7ec8f7;">URL:</b> adb-xxx.azuredatabricks.net<br/><br/>
<div style="background:#0a1a2a;border-radius:6px;padding:8px;font-size:11px;color:#aaa;">
✅ Best for enterprise<br/>
✅ Power BI native<br/>
✅ Office 365 integration<br/>
✅ Bank/govt compliance<br/>
<span style="color:#f4a61e;">⭐ What we use in RetailPulse</span>
</div>
</div></div>

<div style="background:#1a2000;border-radius:10px;overflow:hidden;">
<div style="background:#ff9900;padding:10px 14px;font-weight:bold;color:#000;font-size:13px;">Amazon AWS</div>
<div style="padding:12px 14px;font-size:11px;color:#ccc;line-height:1.9;">
<b style="color:#ffd966;">Storage:</b> S3<br/>
<b style="color:#ffd966;">Secrets:</b> Secrets Manager<br/>
<b style="color:#ffd966;">Identity:</b> IAM<br/>
<b style="color:#ffd966;">Pipeline:</b> AWS Glue<br/>
<b style="color:#ffd966;">URL:</b> xxx.cloud.databricks.com<br/><br/>
<div style="background:#0a0f00;border-radius:6px;padding:8px;font-size:11px;color:#aaa;">
✅ Most mature cloud<br/>
✅ Popular in startups<br/>
✅ Most engineers know it<br/>
✅ Cheapest compute<br/>
</div>
</div></div>

<div style="background:#002a1a;border-radius:10px;overflow:hidden;">
<div style="background:#34a853;padding:10px 14px;font-weight:bold;color:#fff;font-size:13px;">Google GCP</div>
<div style="padding:12px 14px;font-size:11px;color:#ccc;line-height:1.9;">
<b style="color:#7defa1;">Storage:</b> Google Cloud Storage<br/>
<b style="color:#7defa1;">Secrets:</b> Secret Manager<br/>
<b style="color:#7defa1;">Identity:</b> Cloud IAM<br/>
<b style="color:#7defa1;">Pipeline:</b> Cloud Dataflow<br/>
<b style="color:#7defa1;">URL:</b> xxx.gcp.databricks.com<br/><br/>
<div style="background:#001a0a;border-radius:6px;padding:8px;font-size:11px;color:#aaa;">
✅ Best for ML workloads<br/>
✅ BigQuery integration<br/>
✅ TensorFlow native<br/>
✅ Kubernetes origin<br/>
</div>
</div></div>

</div>

<h3 style="color:#888;font-size:12px;letter-spacing:1px;margin-top:4px;">WHY AZURE DOMINATES ENTERPRISE</h3>
<div style="display:grid;grid-template-columns:1fr 1fr 1fr 1fr;gap:8px;margin-bottom:12px;">
<div style="background:#1a2a3a;border-radius:8px;padding:10px 12px;text-align:center;">
<div style="font-size:20px;">🏢</div>
<div style="font-size:11px;color:#7ec8f7;font-weight:bold;margin:4px 0;">Office 365</div>
<div style="font-size:10px;color:#888;">Teams + Outlook already in every company</div>
</div>
<div style="background:#1a2a3a;border-radius:8px;padding:10px 12px;text-align:center;">
<div style="font-size:20px;">🔐</div>
<div style="font-size:11px;color:#7ec8f7;font-weight:bold;margin:4px 0;">Azure AD</div>
<div style="font-size:10px;color:#888;">Same login employees already use</div>
</div>
<div style="background:#1a2a3a;border-radius:8px;padding:10px 12px;text-align:center;">
<div style="font-size:20px;">📊</div>
<div style="font-size:11px;color:#7ec8f7;font-weight:bold;margin:4px 0;">Power BI</div>
<div style="font-size:10px;color:#888;">Connects natively to Gold layer</div>
</div>
<div style="background:#1a2a3a;border-radius:8px;padding:10px 12px;text-align:center;">
<div style="font-size:20px;">🏦</div>
<div style="font-size:11px;color:#7ec8f7;font-weight:bold;margin:4px 0;">Compliance</div>
<div style="font-size:10px;color:#888;">Banks and governments trust it</div>
</div>
</div>

<div style="background:#2a2a2a;border-radius:8px;padding:10px 14px;font-size:11px;color:#aaa;">
<b style="color:#f4a61e;">Our course uses Azure throughout.</b> S8 covers Azure deeply — ADLS Gen2, Key Vault, ADF, Azure SQL. Everything in RetailPulse is Azure-native.
</div>

</div>
""")
